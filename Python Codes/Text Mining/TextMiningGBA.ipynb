# %%
import pandas as pd

spotify_df = pd.read_csv("SpotifyAppReview_Sample.csv", na_filter = True)
spotify_df
# Out:
#      Review ID                                             Review  Rating  \
# 0            1                     Keeps crashing on my s22 ultra     1.0
# 1            2                                Good app Good music     5.0
# 2            3  PREMIUM BUYERS: READ B4 U BUY Guys, the app's ...     3.0
# 3            4  Best Music Streaming App for Android and Ios. ...     5.0
# 4            5                           Best aap to listen music     5.0
# ..         ...                                                ...     ...
# 154        155                                                 na     NaN
# 155        156    Really buggy and terrible to use as of recently     1.0
# 156        157  This pop-up Get the best Spotify experience on...     4.0
# 157        158  Please ignore previous negative rating. This a...     5.0
# 158        159  Great music service, the audio is high quality...     5.0
#
#      Total_thumbsup
# 0               0.0
# 1               0.0
# ...

# %%
duplicates = spotify_df.duplicated()
total_duplicates = duplicates.sum()

print("Total duplicates:", total_duplicates)
# Out:
# Total duplicates: 0
