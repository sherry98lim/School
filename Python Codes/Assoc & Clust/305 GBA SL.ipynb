# %% [markdown]
# ### Assoc and Clust

# %%
import pandas as pd
import matplotlib.pyplot as plt

game_df = pd.read_csv("appstore_games.csv", na_filter = True)
game_df
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  1474626442
# 17003  https://apps.apple.com/us/app/eachother/id1474...  1474919257
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  1474962324
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  1474963671
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  1475076711
#
#                             Name                        Subtitle  \
# 0                         Sudoku                             NaN
# 1                        Reversi                             NaN
# 2                        Morocco                             NaN
# 3                  Sudoku (Free)                             NaN
# 4                   Senet Deluxe                             NaN
# ...                          ...                             ...
# 17002  Stack Puzzle : Rise Tower  Blast the cubes, solve puzzle!
# 17003                  EachOther                             NaN
# 17004         Rabbit Vs Tortoise                             NaN
# 17005                     FaTaLL                Most fun game!!!
# 17006   The Three Kingdoms :Bomb                             NaN
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 3      https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 17002  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17003  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17004  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17005  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17006  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
#
#        User Rating Count  Price   In-app Purchases  \
# 0                 3553.0   2.99                NaN
# 1                  284.0   1.99                NaN
# 2                 8376.0   0.00                NaN
# 3               190394.0   0.00                NaN
# 4                   28.0   2.99                NaN
# ...                  ...    ...                ...
# 17002                NaN   0.00                NaN
# 17003                NaN   0.00                NaN
# 17004                NaN   0.00                NaN
# 17005                NaN   0.00  9.99, 49.99, 3.99
# 17006                NaN   0.00                NaN
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 3      Top 100 free app for over a year.\nRated "Best...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# ...                                                  ...
# 17002  The goal is very simple, move the square horiz...
# 17003  Collect a score while you play!!\n\nBy linking...
# 17004  "Rabbit Vs Tortoise is chess type cool simple ...
# 17005  Upgrade your character and use your skills to ...
# 17006  The protagonist uses the method of placing a b...
#
#                       Developer Age Rating  \
# 0      Mighty Mighty Good Games         4+
# 1              Kiss The Machine         4+
# 2                   Bayou Games         4+
# 3      Mighty Mighty Good Games         4+
# 4               RoGame Software         4+
# ...                         ...        ...
# 17002               Zhigang Pei         4+
# 17003             Sultan Shindi         4+
# 17004             Vishal Baldha         4+
# 17005              Tayrem Games         4+
# 17006              ming bo tang         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 17002                                                 EN   64795648.0
# 17003                                                 EN  110341120.0
# 17004                                                 EN   23207936.0
# 17005                                                 EN  196750336.0
# 17006                                             EN, ZH   22952960.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 17002         Games  Games, Entertainment, Casual, Strategy
# 17003         Games                 Games, Family, Strategy
# 17004         Games                         Games, Strategy
# 17005         Games                 Games, Strategy, Action
# 17006         Games                 Games, Strategy, Puzzle
#
#       Original Release Date Current Version Release Date
# 0                11/07/2008                   30/05/2017
# 1                11/07/2008                   17/05/2018
# 2                11/07/2008                    5/09/2017
# 3                23/07/2008                   30/05/2017
# 4                18/07/2008                   22/07/2018
# ...                     ...                          ...
# 17002            30/07/2019                   30/07/2019
# 17003             1/08/2019                    1/08/2019
# 17004             3/08/2019                    3/08/2019
# 17005             1/08/2019                    1/08/2019
# 17006             2/08/2019                    2/08/2019
#
# [17007 rows x 18 columns]

# %%
game_df.isnull().sum(axis=0)
# Out:
# URL                                 0
# ID                                  0
# Name                                0
# Subtitle                        11746
# Icon URL                            0
# Average User Rating              9446
# User Rating Count                9446
# Price                              24
# In-app Purchases                 9324
# Description                         0
# Developer                           0
# Age Rating                          0
# Languages                          60
# Size                                1
# Primary Genre                       0
# Genres                              0
# Original Release Date               0
# Current Version Release Date        0
# dtype: int64

# %%
duplicates = game_df.duplicated()
total_duplicates = duplicates.sum()

print("Total duplicates:", total_duplicates)
# Out:
# Total duplicates: 160

# %%
game_df1 = game_df.drop_duplicates()

display(game_df1)
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  1474626442
# 17003  https://apps.apple.com/us/app/eachother/id1474...  1474919257
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  1474962324
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  1474963671
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  1475076711
#
#                             Name                        Subtitle  \
# 0                         Sudoku                             NaN
# 1                        Reversi                             NaN
# 2                        Morocco                             NaN
# 3                  Sudoku (Free)                             NaN
# 4                   Senet Deluxe                             NaN
# ...                          ...                             ...
# 17002  Stack Puzzle : Rise Tower  Blast the cubes, solve puzzle!
# 17003                  EachOther                             NaN
# 17004         Rabbit Vs Tortoise                             NaN
# 17005                     FaTaLL                Most fun game!!!
# 17006   The Three Kingdoms :Bomb                             NaN
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 3      https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 17002  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17003  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17004  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17005  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17006  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
#
#        User Rating Count  Price   In-app Purchases  \
# 0                 3553.0   2.99                NaN
# 1                  284.0   1.99                NaN
# 2                 8376.0   0.00                NaN
# 3               190394.0   0.00                NaN
# 4                   28.0   2.99                NaN
# ...                  ...    ...                ...
# 17002                NaN   0.00                NaN
# 17003                NaN   0.00                NaN
# 17004                NaN   0.00                NaN
# 17005                NaN   0.00  9.99, 49.99, 3.99
# 17006                NaN   0.00                NaN
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 3      Top 100 free app for over a year.\nRated "Best...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# ...                                                  ...
# 17002  The goal is very simple, move the square horiz...
# 17003  Collect a score while you play!!\n\nBy linking...
# 17004  "Rabbit Vs Tortoise is chess type cool simple ...
# 17005  Upgrade your character and use your skills to ...
# 17006  The protagonist uses the method of placing a b...
#
#                       Developer Age Rating  \
# 0      Mighty Mighty Good Games         4+
# 1              Kiss The Machine         4+
# 2                   Bayou Games         4+
# 3      Mighty Mighty Good Games         4+
# 4               RoGame Software         4+
# ...                         ...        ...
# 17002               Zhigang Pei         4+
# 17003             Sultan Shindi         4+
# 17004             Vishal Baldha         4+
# 17005              Tayrem Games         4+
# 17006              ming bo tang         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 17002                                                 EN   64795648.0
# 17003                                                 EN  110341120.0
# 17004                                                 EN   23207936.0
# 17005                                                 EN  196750336.0
# 17006                                             EN, ZH   22952960.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 17002         Games  Games, Entertainment, Casual, Strategy
# 17003         Games                 Games, Family, Strategy
# 17004         Games                         Games, Strategy
# 17005         Games                 Games, Strategy, Action
# 17006         Games                 Games, Strategy, Puzzle
#
#       Original Release Date Current Version Release Date
# 0                11/07/2008                   30/05/2017
# 1                11/07/2008                   17/05/2018
# 2                11/07/2008                    5/09/2017
# 3                23/07/2008                   30/05/2017
# 4                18/07/2008                   22/07/2018
# ...                     ...                          ...
# 17002            30/07/2019                   30/07/2019
# 17003             1/08/2019                    1/08/2019
# 17004             3/08/2019                    3/08/2019
# 17005             1/08/2019                    1/08/2019
# 17006             2/08/2019                    2/08/2019
#
# [16847 rows x 18 columns]

# %%
clean1 = game_df1.drop(['URL', 'Subtitle', 'Icon URL','Description', 'Developer','Original Release Date'], axis=1)

display(clean1)
# Out:
#                ID                       Name  Average User Rating  \
# 0       284921427                     Sudoku                  4.0
# 1       284926400                    Reversi                  3.5
# 2       284946595                    Morocco                  3.0
# 3       285755462              Sudoku (Free)                  3.5
# 4       285831220               Senet Deluxe                  3.5
# ...           ...                        ...                  ...
# 17002  1474626442  Stack Puzzle : Rise Tower                  NaN
# 17003  1474919257                  EachOther                  NaN
# 17004  1474962324         Rabbit Vs Tortoise                  NaN
# 17005  1474963671                     FaTaLL                  NaN
# 17006  1475076711   The Three Kingdoms :Bomb                  NaN
#
#        User Rating Count  Price   In-app Purchases Age Rating  \
# 0                 3553.0   2.99                NaN         4+
# 1                  284.0   1.99                NaN         4+
# 2                 8376.0   0.00                NaN         4+
# 3               190394.0   0.00                NaN         4+
# 4                   28.0   2.99                NaN         4+
# ...                  ...    ...                ...        ...
# 17002                NaN   0.00                NaN         4+
# 17003                NaN   0.00                NaN         4+
# 17004                NaN   0.00                NaN         4+
# 17005                NaN   0.00  9.99, 49.99, 3.99         4+
# 17006                NaN   0.00                NaN         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 17002                                                 EN   64795648.0
# 17003                                                 EN  110341120.0
# 17004                                                 EN   23207936.0
# 17005                                                 EN  196750336.0
# 17006                                             EN, ZH   22952960.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 17002         Games  Games, Entertainment, Casual, Strategy
# 17003         Games                 Games, Family, Strategy
# 17004         Games                         Games, Strategy
# 17005         Games                 Games, Strategy, Action
# 17006         Games                 Games, Strategy, Puzzle
#
#       Current Version Release Date
# 0                       30/05/2017
# 1                       17/05/2018
# 2                        5/09/2017
# 3                       30/05/2017
# 4                       22/07/2018
# ...                            ...
# 17002                   30/07/2019
# 17003                    1/08/2019
# 17004                    3/08/2019
# 17005                    1/08/2019
# 17006                    2/08/2019
#
# [16847 rows x 12 columns]

# %%
# Remove languages and user rating count null

clean2 = clean1.dropna(subset=['User Rating Count','Languages'])
display(clean2)
# Out:
#                ID                   Name  Average User Rating  \
# 0       284921427                 Sudoku                  4.0
# 1       284926400                Reversi                  3.5
# 2       284946595                Morocco                  3.0
# 3       285755462          Sudoku (Free)                  3.5
# 4       285831220           Senet Deluxe                  3.5
# ...           ...                    ...                  ...
# 16950  1473084135               Die Last                  3.0
# 16956  1473181500            Basic Slosh                  5.0
# 16962  1473559573     Idle Racing Tycoon                  5.0
# 16967  1473680543     Glow Hockey Strike                  5.0
# 16993  1474461379  Agadmator Chess Clock                  5.0
#
#        User Rating Count  Price In-app Purchases Age Rating  \
# 0                 3553.0   2.99              NaN         4+
# 1                  284.0   1.99              NaN         4+
# 2                 8376.0   0.00              NaN         4+
# 3               190394.0   0.00              NaN         4+
# 4                   28.0   2.99              NaN         4+
# ...                  ...    ...              ...        ...
# 16950                6.0   0.00              NaN        12+
# 16956               30.0   0.00              NaN         4+
# 16962               51.0   0.00              NaN         9+
# 16967                5.0   0.00              NaN         4+
# 16993               33.0   0.00              NaN         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 16950                                             EN, ZH  151308288.0
# 16956                                                 EN   79646720.0
# 16962                                                 EN  125348864.0
# 16967                                                 EN  128687104.0
# 16993                                                 EN    8845312.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 16950         Games  Games, Strategy, Entertainment, Puzzle
# 16956         Games  Games, Entertainment, Action, Strategy
# 16962         Games             Games, Simulation, Strategy
# 16967         Games             Games, Simulation, Strategy
# 16993         Games       Games, Strategy, Board, Utilities
#
#       Current Version Release Date
# 0                       30/05/2017
# 1                       17/05/2018
# 2                        5/09/2017
# 3                       30/05/2017
# 4                       22/07/2018
# ...                            ...
# 16950                   31/07/2019
# 16956                   23/07/2019
# 16962                   31/07/2019
# 16967                   28/07/2019
# 16993                   30/07/2019
#
# [7464 rows x 12 columns]

# %%
clean2.isnull().sum(axis=0)
# Out:
# ID                                 0
# Name                               0
# Average User Rating                0
# User Rating Count                  0
# Price                              0
# In-app Purchases                2891
# Age Rating                         0
# Languages                          0
# Size                               0
# Primary Genre                      0
# Genres                             0
# Current Version Release Date       0
# dtype: int64

# %%
# Primary genre = Games
clean3 = clean2[clean2['Primary Genre'] == 'Games']
display(clean3)
# Out:
#                ID                   Name  Average User Rating  \
# 0       284921427                 Sudoku                  4.0
# 1       284926400                Reversi                  3.5
# 2       284946595                Morocco                  3.0
# 3       285755462          Sudoku (Free)                  3.5
# 4       285831220           Senet Deluxe                  3.5
# ...           ...                    ...                  ...
# 16950  1473084135               Die Last                  3.0
# 16956  1473181500            Basic Slosh                  5.0
# 16962  1473559573     Idle Racing Tycoon                  5.0
# 16967  1473680543     Glow Hockey Strike                  5.0
# 16993  1474461379  Agadmator Chess Clock                  5.0
#
#        User Rating Count  Price In-app Purchases Age Rating  \
# 0                 3553.0   2.99              NaN         4+
# 1                  284.0   1.99              NaN         4+
# 2                 8376.0   0.00              NaN         4+
# 3               190394.0   0.00              NaN         4+
# 4                   28.0   2.99              NaN         4+
# ...                  ...    ...              ...        ...
# 16950                6.0   0.00              NaN        12+
# 16956               30.0   0.00              NaN         4+
# 16962               51.0   0.00              NaN         9+
# 16967                5.0   0.00              NaN         4+
# 16993               33.0   0.00              NaN         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 16950                                             EN, ZH  151308288.0
# 16956                                                 EN   79646720.0
# 16962                                                 EN  125348864.0
# 16967                                                 EN  128687104.0
# 16993                                                 EN    8845312.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 16950         Games  Games, Strategy, Entertainment, Puzzle
# 16956         Games  Games, Entertainment, Action, Strategy
# 16962         Games             Games, Simulation, Strategy
# 16967         Games             Games, Simulation, Strategy
# 16993         Games       Games, Strategy, Board, Utilities
#
#       Current Version Release Date
# 0                       30/05/2017
# 1                       17/05/2018
# 2                        5/09/2017
# 3                       30/05/2017
# 4                       22/07/2018
# ...                            ...
# 16950                   31/07/2019
# 16956                   23/07/2019
# 16962                   31/07/2019
# 16967                   28/07/2019
# 16993                   30/07/2019
#
# [7196 rows x 12 columns]

# %%
# Filter out 2019 games
clean4  = clean3[clean3['Current Version Release Date'].str.contains('2019', case=False, na=False)]
display(clean4)
# Out:
#                ID                            Name  Average User Rating  \
# 5       286210009  Sudoku - Classic number puzzle                  3.0
# 13      288689440                          Marple                  3.5
# 19      290614255     Cool Sudoku, Jigsaw, Killer                  3.5
# 27      292538570  Lux Touch 3 - World Domination                  3.5
# 28      292975610                  "Don't Square"                  2.5
# ...           ...                             ...                  ...
# 16950  1473084135                        Die Last                  3.0
# 16956  1473181500                     Basic Slosh                  5.0
# 16962  1473559573              Idle Racing Tycoon                  5.0
# 16967  1473680543              Glow Hockey Strike                  5.0
# 16993  1474461379           Agadmator Chess Clock                  5.0
#
#        User Rating Count  Price  In-app Purchases Age Rating  \
# 5                   47.0   0.00              1.99         4+
# 13                 989.0   0.99               NaN         4+
# 19                 357.0   0.00  0.99, 0.99, 0.99         4+
# 27               72428.0   0.00               NaN         9+
# 28                 190.0   0.99               NaN         4+
# ...                  ...    ...               ...        ...
# 16950                6.0   0.00               NaN        12+
# 16956               30.0   0.00               NaN         4+
# 16962               51.0   0.00               NaN         9+
# 16967                5.0   0.00               NaN         4+
# 16993               33.0   0.00               NaN         4+
#
#                             Languages         Size Primary Genre  \
# 5                                  EN   48672768.0         Games
# 13                                 EN    3643392.0         Games
# 19                                 EN   52236288.0         Games
# 27                                 EN   55071744.0         Games
# 28     EN, FR, DE, EL, PT, RU, ZH, ES    4357120.0         Games
# ...                               ...          ...           ...
# 16950                          EN, ZH  151308288.0         Games
# 16956                              EN   79646720.0         Games
# 16962                              EN  125348864.0         Games
# 16967                              EN  128687104.0         Games
# 16993                              EN    8845312.0         Games
#
#                                        Genres Current Version Release Date
# 5      Games, Entertainment, Strategy, Puzzle                   29/04/2019
# 13                    Games, Puzzle, Strategy                    5/05/2019
# 19     Games, Strategy, Puzzle, Entertainment                   26/04/2019
# 27      Games, Entertainment, Strategy, Board                   23/01/2019
# 28      Games, Board, Entertainment, Strategy                   22/05/2019
# ...                                       ...                          ...
# 16950  Games, Strategy, Entertainment, Puzzle                   31/07/2019
# 16956  Games, Entertainment, Action, Strategy                   23/07/2019
# 16962             Games, Simulation, Strategy                   31/07/2019
# 16967             Games, Simulation, Strategy                   28/07/2019
# 16993       Games, Strategy, Board, Utilities                   30/07/2019
#
# [1957 rows x 12 columns]

# %%
clean5 = clean4[clean4['User Rating Count'] > 500]

display(clean5)
# Out:
#                ID                            Name  Average User Rating  \
# 13      288689440                          Marple                  3.5
# 27      292538570  Lux Touch 3 - World Domination                  3.5
# 33      295445501              Chess - tChess Pro                  4.0
# 36      296756437             Chess - tChess Lite                  3.5
# 40      298748403            Warfare Incorporated                  3.5
# ...           ...                             ...                  ...
# 16525  1461453188        Dead Spreading:Idle Game                  5.0
# 16629  1464482102               Auto Chess:Origin                  4.5
# 16690  1465996312                 Dota Underlords                  4.5
# 16718  1466637212                 Car Wash Empire                  5.0
# 16724  1466987107              Idle Zoo Tycoon 3D                  4.5
#
#        User Rating Count  Price  \
# 13                 989.0   0.99
# 27               72428.0   0.00
# 33                3062.0   7.99
# 36                5488.0   0.99
# 40                5931.0   0.00
# ...                  ...    ...
# 16525             3253.0   0.00
# 16629             2943.0   0.00
# 16690             3511.0   0.00
# 16718              658.0   0.00
# 16724             1197.0   0.00
#
#                                         In-app Purchases Age Rating  \
# 13                                                   NaN         4+
# 27                                                   NaN         9+
# 33                                                   NaN         4+
# 36                                                   NaN         4+
# 40                                                   NaN         9+
# ...                                                  ...        ...
# 16525  4.99, 4.99, 0.99, 4.99, 9.99, 19.99, 49.99, 99.99        12+
# 16629  0.99, 9.99, 19.99, 4.99, 9.99, 4.99, 1.99, 49....        12+
# 16690                                                NaN        12+
# 16718                                               2.99         4+
# 16724                                                NaN        12+
#
#                                                Languages         Size  \
# 13                                                    EN    3643392.0
# 27                                                    EN   55071744.0
# 33                                EN, FR, DE, JA, KO, ZH    7517184.0
# 36                                EN, FR, DE, JA, KO, ZH    5874688.0
# 40                                                    EN    7705600.0
# ...                                                  ...          ...
# 16525                                                 EN  214971392.0
# 16629                                                 EN  775446528.0
# 16690  BG, CS, DA, NL, EN, FI, FR, DE, HU, IT, JA, KO...  715730944.0
# 16718                                                 EN  206372864.0
# 16724                                                 EN  131396608.0
#
#       Primary Genre                                  Genres  \
# 13            Games                 Games, Puzzle, Strategy
# 27            Games   Games, Entertainment, Strategy, Board
# 33            Games   Games, Board, Entertainment, Strategy
# 36            Games   Games, Strategy, Entertainment, Board
# 40            Games  Games, Strategy, Entertainment, Action
# ...             ...                                     ...
# 16525         Games             Games, Simulation, Strategy
# 16629         Games                         Games, Strategy
# 16690         Games                         Games, Strategy
# 16718         Games  Games, Strategy, Puzzle, Entertainment
# 16724         Games                 Games, Action, Strategy
#
#       Current Version Release Date
# 13                       5/05/2019
# 27                      23/01/2019
# 33                       7/04/2019
# 36                       7/04/2019
# 40                      20/06/2019
# ...                            ...
# 16525                   26/07/2019
# 16629                   30/07/2019
# 16690                    2/08/2019
# 16718                   30/07/2019
# 16724                    1/08/2019
#
# [695 rows x 12 columns]

# %%
# Split the 'Languages' column by comma and count the number of languages
clean5['Number of Languages'] = clean5['Languages'].apply(lambda x: len(x.split(', ')))

display(clean5)
# Out:
# C:\Users\sherr\AppData\Local\Temp\ipykernel_12912\2373775089.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean5['Number of Languages'] = clean5['Languages'].apply(lambda x: len(x.split(', ')))
#                ID                            Name  Average User Rating  \
# 13      288689440                          Marple                  3.5
# 27      292538570  Lux Touch 3 - World Domination                  3.5
# 33      295445501              Chess - tChess Pro                  4.0
# 36      296756437             Chess - tChess Lite                  3.5
# 40      298748403            Warfare Incorporated                  3.5
# ...           ...                             ...                  ...
# 16525  1461453188        Dead Spreading:Idle Game                  5.0
# 16629  1464482102               Auto Chess:Origin                  4.5
# 16690  1465996312                 Dota Underlords                  4.5
# 16718  1466637212                 Car Wash Empire                  5.0
# 16724  1466987107              Idle Zoo Tycoon 3D                  4.5
#
#        User Rating Count  Price  \
# 13                 989.0   0.99
# 27               72428.0   0.00
# 33                3062.0   7.99
# 36                5488.0   0.99
# 40                5931.0   0.00
# ...                  ...    ...
# 16525             3253.0   0.00
# 16629             2943.0   0.00
# 16690             3511.0   0.00
# 16718              658.0   0.00
# 16724             1197.0   0.00
#
#                                         In-app Purchases Age Rating  \
# 13                                                   NaN         4+
# 27                                                   NaN         9+
# 33                                                   NaN         4+
# 36                                                   NaN         4+
# 40                                                   NaN         9+
# ...                                                  ...        ...
# 16525  4.99, 4.99, 0.99, 4.99, 9.99, 19.99, 49.99, 99.99        12+
# 16629  0.99, 9.99, 19.99, 4.99, 9.99, 4.99, 1.99, 49....        12+
# 16690                                                NaN        12+
# 16718                                               2.99         4+
# 16724                                                NaN        12+
#
#                                                Languages         Size  \
# 13                                                    EN    3643392.0
# 27                                                    EN   55071744.0
# 33                                EN, FR, DE, JA, KO, ZH    7517184.0
# 36                                EN, FR, DE, JA, KO, ZH    5874688.0
# 40                                                    EN    7705600.0
# ...                                                  ...          ...
# 16525                                                 EN  214971392.0
# 16629                                                 EN  775446528.0
# 16690  BG, CS, DA, NL, EN, FI, FR, DE, HU, IT, JA, KO...  715730944.0
# 16718                                                 EN  206372864.0
# 16724                                                 EN  131396608.0
#
#       Primary Genre                                  Genres  \
# 13            Games                 Games, Puzzle, Strategy
# 27            Games   Games, Entertainment, Strategy, Board
# 33            Games   Games, Board, Entertainment, Strategy
# 36            Games   Games, Strategy, Entertainment, Board
# 40            Games  Games, Strategy, Entertainment, Action
# ...             ...                                     ...
# 16525         Games             Games, Simulation, Strategy
# 16629         Games                         Games, Strategy
# 16690         Games                         Games, Strategy
# 16718         Games  Games, Strategy, Puzzle, Entertainment
# 16724         Games                 Games, Action, Strategy
#
#       Current Version Release Date  Number of Languages
# 13                       5/05/2019                    1
# 27                      23/01/2019                    1
# 33                       7/04/2019                    6
# 36                       7/04/2019                    6
# 40                      20/06/2019                    1
# ...                            ...                  ...
# 16525                   26/07/2019                    1
# 16629                   30/07/2019                    1
# 16690                    2/08/2019                   25
# 16718                   30/07/2019                    1
# 16724                    1/08/2019                    1
#
# [695 rows x 13 columns]

# %%
# Split the 'Genres' column by comma and count the number of genres
clean5['Number of Genres'] = clean5['Genres'].apply(lambda x: len(x.split(', ')))

display(clean5)
# Out:
# C:\Users\sherr\AppData\Local\Temp\ipykernel_12912\2319024686.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean5['Number of Genres'] = clean5['Genres'].apply(lambda x: len(x.split(', ')))
#                ID                            Name  Average User Rating  \
# 13      288689440                          Marple                  3.5
# 27      292538570  Lux Touch 3 - World Domination                  3.5
# 33      295445501              Chess - tChess Pro                  4.0
# 36      296756437             Chess - tChess Lite                  3.5
# 40      298748403            Warfare Incorporated                  3.5
# ...           ...                             ...                  ...
# 16525  1461453188        Dead Spreading:Idle Game                  5.0
# 16629  1464482102               Auto Chess:Origin                  4.5
# 16690  1465996312                 Dota Underlords                  4.5
# 16718  1466637212                 Car Wash Empire                  5.0
# 16724  1466987107              Idle Zoo Tycoon 3D                  4.5
#
#        User Rating Count  Price  \
# 13                 989.0   0.99
# 27               72428.0   0.00
# 33                3062.0   7.99
# 36                5488.0   0.99
# 40                5931.0   0.00
# ...                  ...    ...
# 16525             3253.0   0.00
# 16629             2943.0   0.00
# 16690             3511.0   0.00
# 16718              658.0   0.00
# 16724             1197.0   0.00
#
#                                         In-app Purchases Age Rating  \
# 13                                                   NaN         4+
# 27                                                   NaN         9+
# 33                                                   NaN         4+
# 36                                                   NaN         4+
# 40                                                   NaN         9+
# ...                                                  ...        ...
# 16525  4.99, 4.99, 0.99, 4.99, 9.99, 19.99, 49.99, 99.99        12+
# 16629  0.99, 9.99, 19.99, 4.99, 9.99, 4.99, 1.99, 49....        12+
# 16690                                                NaN        12+
# 16718                                               2.99         4+
# 16724                                                NaN        12+
#
#                                                Languages         Size  \
# 13                                                    EN    3643392.0
# 27                                                    EN   55071744.0
# 33                                EN, FR, DE, JA, KO, ZH    7517184.0
# 36                                EN, FR, DE, JA, KO, ZH    5874688.0
# 40                                                    EN    7705600.0
# ...                                                  ...          ...
# 16525                                                 EN  214971392.0
# 16629                                                 EN  775446528.0
# 16690  BG, CS, DA, NL, EN, FI, FR, DE, HU, IT, JA, KO...  715730944.0
# 16718                                                 EN  206372864.0
# 16724                                                 EN  131396608.0
#
#       Primary Genre                                  Genres  \
# 13            Games                 Games, Puzzle, Strategy
# 27            Games   Games, Entertainment, Strategy, Board
# 33            Games   Games, Board, Entertainment, Strategy
# 36            Games   Games, Strategy, Entertainment, Board
# 40            Games  Games, Strategy, Entertainment, Action
# ...             ...                                     ...
# 16525         Games             Games, Simulation, Strategy
# 16629         Games                         Games, Strategy
# 16690         Games                         Games, Strategy
# 16718         Games  Games, Strategy, Puzzle, Entertainment
# 16724         Games                 Games, Action, Strategy
#
#       Current Version Release Date  Number of Languages  Number of Genres
# 13                       5/05/2019                    1                 3
# 27                      23/01/2019                    1                 4
# 33                       7/04/2019                    6                 4
# 36                       7/04/2019                    6                 4
# 40                      20/06/2019                    1                 4
# ...                            ...                  ...               ...
# 16525                   26/07/2019                    1                 3
# 16629                   30/07/2019                    1                 2
# 16690                    2/08/2019                   25                 2
# 16718                   30/07/2019                    1                 4
# 16724                    1/08/2019                    1                 3
#
# [695 rows x 14 columns]

# %%
clean5['In-App Purchase Present'] = clean5['In-app Purchases'].isnull().replace({True: 'Y', False: 'N'})
display (clean5)
# Out:
# C:\Users\sherr\AppData\Local\Temp\ipykernel_12912\4240475341.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean5['In-App Purchase Present'] = clean5['In-app Purchases'].isnull().replace({True: 'Y', False: 'N'})
#                ID                            Name  Average User Rating  \
# 13      288689440                          Marple                  3.5
# 27      292538570  Lux Touch 3 - World Domination                  3.5
# 33      295445501              Chess - tChess Pro                  4.0
# 36      296756437             Chess - tChess Lite                  3.5
# 40      298748403            Warfare Incorporated                  3.5
# ...           ...                             ...                  ...
# 16525  1461453188        Dead Spreading:Idle Game                  5.0
# 16629  1464482102               Auto Chess:Origin                  4.5
# 16690  1465996312                 Dota Underlords                  4.5
# 16718  1466637212                 Car Wash Empire                  5.0
# 16724  1466987107              Idle Zoo Tycoon 3D                  4.5
#
#        User Rating Count  Price  \
# 13                 989.0   0.99
# 27               72428.0   0.00
# 33                3062.0   7.99
# 36                5488.0   0.99
# 40                5931.0   0.00
# ...                  ...    ...
# 16525             3253.0   0.00
# 16629             2943.0   0.00
# 16690             3511.0   0.00
# 16718              658.0   0.00
# 16724             1197.0   0.00
#
#                                         In-app Purchases Age Rating  \
# 13                                                   NaN         4+
# 27                                                   NaN         9+
# 33                                                   NaN         4+
# 36                                                   NaN         4+
# 40                                                   NaN         9+
# ...                                                  ...        ...
# 16525  4.99, 4.99, 0.99, 4.99, 9.99, 19.99, 49.99, 99.99        12+
# 16629  0.99, 9.99, 19.99, 4.99, 9.99, 4.99, 1.99, 49....        12+
# 16690                                                NaN        12+
# 16718                                               2.99         4+
# 16724                                                NaN        12+
#
#                                                Languages         Size  \
# 13                                                    EN    3643392.0
# 27                                                    EN   55071744.0
# 33                                EN, FR, DE, JA, KO, ZH    7517184.0
# 36                                EN, FR, DE, JA, KO, ZH    5874688.0
# 40                                                    EN    7705600.0
# ...                                                  ...          ...
# 16525                                                 EN  214971392.0
# 16629                                                 EN  775446528.0
# 16690  BG, CS, DA, NL, EN, FI, FR, DE, HU, IT, JA, KO...  715730944.0
# 16718                                                 EN  206372864.0
# 16724                                                 EN  131396608.0
#
#       Primary Genre                                  Genres  \
# 13            Games                 Games, Puzzle, Strategy
# 27            Games   Games, Entertainment, Strategy, Board
# 33            Games   Games, Board, Entertainment, Strategy
# 36            Games   Games, Strategy, Entertainment, Board
# 40            Games  Games, Strategy, Entertainment, Action
# ...             ...                                     ...
# 16525         Games             Games, Simulation, Strategy
# 16629         Games                         Games, Strategy
# 16690         Games                         Games, Strategy
# 16718         Games  Games, Strategy, Puzzle, Entertainment
# 16724         Games                 Games, Action, Strategy
#
#       Current Version Release Date  Number of Languages  Number of Genres  \
# 13                       5/05/2019                    1                 3
# 27                      23/01/2019                    1                 4
# 33                       7/04/2019                    6                 4
# 36                       7/04/2019                    6                 4
# 40                      20/06/2019                    1                 4
# ...                            ...                  ...               ...
# 16525                   26/07/2019                    1                 3
# 16629                   30/07/2019                    1                 2
# 16690                    2/08/2019                   25                 2
# 16718                   30/07/2019                    1                 4
# 16724                    1/08/2019                    1                 3
#
#       In-App Purchase Present
# 13                          Y
# 27                          Y
# 33                          Y
# 36                          Y
# 40                          Y
# ...                       ...
# 16525                       N
# 16629                       N
# 16690                       Y
# 16718                       N
# 16724                       Y
#
# [695 rows x 15 columns]

# %%
clean6 = clean5.drop(['Name','Primary Genre','Current Version Release Date'], axis=1)

display(clean6)
# Out:
#                ID  Average User Rating  User Rating Count  Price  \
# 13      288689440                  3.5              989.0   0.99
# 27      292538570                  3.5            72428.0   0.00
# 33      295445501                  4.0             3062.0   7.99
# 36      296756437                  3.5             5488.0   0.99
# 40      298748403                  3.5             5931.0   0.00
# ...           ...                  ...                ...    ...
# 16525  1461453188                  5.0             3253.0   0.00
# 16629  1464482102                  4.5             2943.0   0.00
# 16690  1465996312                  4.5             3511.0   0.00
# 16718  1466637212                  5.0              658.0   0.00
# 16724  1466987107                  4.5             1197.0   0.00
#
#                                         In-app Purchases Age Rating  \
# 13                                                   NaN         4+
# 27                                                   NaN         9+
# 33                                                   NaN         4+
# 36                                                   NaN         4+
# 40                                                   NaN         9+
# ...                                                  ...        ...
# 16525  4.99, 4.99, 0.99, 4.99, 9.99, 19.99, 49.99, 99.99        12+
# 16629  0.99, 9.99, 19.99, 4.99, 9.99, 4.99, 1.99, 49....        12+
# 16690                                                NaN        12+
# 16718                                               2.99         4+
# 16724                                                NaN        12+
#
#                                                Languages         Size  \
# 13                                                    EN    3643392.0
# 27                                                    EN   55071744.0
# 33                                EN, FR, DE, JA, KO, ZH    7517184.0
# 36                                EN, FR, DE, JA, KO, ZH    5874688.0
# 40                                                    EN    7705600.0
# ...                                                  ...          ...
# 16525                                                 EN  214971392.0
# 16629                                                 EN  775446528.0
# 16690  BG, CS, DA, NL, EN, FI, FR, DE, HU, IT, JA, KO...  715730944.0
# 16718                                                 EN  206372864.0
# 16724                                                 EN  131396608.0
#
#                                        Genres  Number of Languages  \
# 13                    Games, Puzzle, Strategy                    1
# 27      Games, Entertainment, Strategy, Board                    1
# 33      Games, Board, Entertainment, Strategy                    6
# 36      Games, Strategy, Entertainment, Board                    6
# 40     Games, Strategy, Entertainment, Action                    1
# ...                                       ...                  ...
# 16525             Games, Simulation, Strategy                    1
# 16629                         Games, Strategy                    1
# 16690                         Games, Strategy                   25
# 16718  Games, Strategy, Puzzle, Entertainment                    1
# 16724                 Games, Action, Strategy                    1
#
#        Number of Genres In-App Purchase Present
# 13                    3                       Y
# 27                    4                       Y
# 33                    4                       Y
# 36                    4                       Y
# 40                    4                       Y
# ...                 ...                     ...
# 16525                 3                       N
# 16629                 2                       N
# 16690                 2                       Y
# 16718                 4                       N
# 16724                 3                       Y
#
# [695 rows x 12 columns]

# %%
clean6.to_csv('305GBASL.csv', index=False)

# %%
## finding all IAP record is null
#df = pd.DataFrame(clean5)
#nan_iap = df[clean5['In-app Purchases'].isna()]
#display(nan_iap)

# %%
#nan_iap.shape

# %%
## finding rows that Languages is NA
#df = pd.DataFrame(game_df)
#nan_lang = df[game_df['Languages'].isna()]
#display (nan_lang)

# %%
#clean5[['Genre1', 'Genre2', 'Genre3',' Genre4']] = clean5['Genres'].str.split(',', expand=True)
# display(clean5)
